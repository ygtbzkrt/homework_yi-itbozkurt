# %%
from __future__ import print_function, division
import numpy as np
import pandas as pd
import nsfg

# %%
from __future__ import print_function, division
import numpy as np
import pandas as pd
import nsfg

# %%
resp = nsfg.ReadFemResp()

# %%
resp.head(20)
# Out:
#     caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0     2298        1         5         5            1          5.0     27
# 1     5012        1         5         1            5          5.0     42
# 2    11586        1         5         1            5          5.0     43
# 3     6794        5         5         4            1          5.0     15
# 4      616        1         5         4            1          5.0     20
# 5      845        1         5         4            1          5.0     42
# 6    10333        5         5         3            1          5.0     17
# 7      855        5         5         4            5          5.0     22
# 8     8656        5         5         4            1          5.0     38
# 9     3566        5         5         4            5          5.0     21
# 10    5917        1         5         3            1          5.0     44
# 11    9200        5         5         3            1          5.0     26
# ...

# %%
resp.columns[0:20]
# Out:
# Index([u'caseid', u'rscrinf', u'rdormres', u'rostscrn', u'rscreenhisp',
#        u'rscreenrace', u'age_a', u'age_r', u'cmbirth', u'agescrn', u'marstat',
#        u'fmarstat', u'fmarit', u'evrmarry', u'hisp', u'hispgrp', u'numrace',
#        u'roscnt', u'hplocale', u'manrel'],
#       dtype='object')

# %%
resp.columns
# Out:
# Index([u'caseid', u'rscrinf', u'rdormres', u'rostscrn', u'rscreenhisp',
#        u'rscreenrace', u'age_a', u'age_r', u'cmbirth', u'agescrn',
#        ...
#        u'pubassis_i', u'basewgt', u'adj_mod_basewgt', u'finalwgt', u'secu_r',
#        u'sest', u'cmintvw', u'cmlstyr', u'screentime', u'intvlngth'],
#       dtype='object', length=3087)

# %%
resp[-30:]
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 7613    4640        5         5         6            5          5.0     18
# 7614    3998        5         5         2            5          5.0     24
# 7615    2432        5         5         5            5          5.0     15
# 7616    5438        1         5         3            5          5.0     30
# 7617    9643        1         5         2            5          5.0     24
# 7618    3030        1         5         1            5          5.0     34
# 7619   11585        1         5         4            5          5.0     34
# 7620    6677        1         5         4            1          5.0     26
# 7621   10744        5         5         8            5          1.0     22
# 7622    8403        5         5         4            5          5.0     19
# 7623    7574        5         5         4            5          5.0     19
# ...

# %%
rows, columns = resp.shape
str(rows)+'rows and  '+str(columns)+'colums'
# Out:
# '7643rows and  3087colums'

# %%
agescrn = resp['agescrn']

# %%
agescrn
# Out:
# 0       27
# 1       42
# 2       43
# 3       15
# 4       20
# 5       42
# 6       17
# 7       22
# 8       38
# 9       21
# 10      43
# 11      26
# 12      23
# 13      34
# 14      28
# 15      28
# 16      23
# 17      33
# 18      16
# 19      24
# 20      22
# 21      32
# 22      41
# 23      37
# 24      38
# 25      29
# 26      21
# 27      37
# 28      39
# 29      26
#         ..
# 7613    18
# 7614    24
# 7615    15
# 7616    30
# 7617    24
# 7618    34
# 7619    34
# 7620    26
# 7621    22
# 7622    19
# 7623    19
# 7624    37
# 7625    20
# 7626    23
# 7627    23
# 7628    17
# 7629    36
# 7630    44
# 7631    32
# 7632    40
# 7633    35
# 7634    35
# 7635    30
# 7636    41
# 7637    35
# 7638    34
# 7639    17
# 7640    29
# 7641    16
# 7642    28
# Name: agescrn, Length: 7643, dtype: int64

# %%
resp.agescrn.value_counts()
# Out:
# 30    292
# 22    287
# 23    282
# 31    278
# 32    273
# 37    271
# 24    269
# 21    267
# 25    267
# 36    266
# 35    262
# 29    262
# 26    260
# 20    258
# 33    257
# 38    256
# 40    256
# 34    255
# 27    255
# 43    253
# 28    252
# 41    250
# 19    241
# 44    235
# 18    235
# 17    234
# 16    223
# 15    217
# 39    215
# 42    215
# Name: agescrn, dtype: int64

# %%
resp.agescrn.min()
# Out:
# 15

# %%
resp.agescrn.max()
# Out:
# 44

# %%
resp.agescrn.min()
# Out:
# 15

# %%
resp[resp.agescrn <= 25]
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 3       6794        5         5         4            1          5.0     15
# 4        616        1         5         4            1          5.0     20
# 6      10333        5         5         3            1          5.0     17
# 7        855        5         5         4            5          5.0     22
# 9       3566        5         5         4            5          5.0     21
# 12      6320        5         5         5            5          1.0     23
# 16      4881        1         5         5            1          5.0     23
# 18      8542        5         5         5            5          5.0     16
# 19      2054        1         5         4            5          1.0     24
# 20      3719        5         5         2            5          5.0     22
# 26      8358        5         5         4            5          5.0     21
# ...

# %%
resp.agescrn.mean()
# Out:
# 29.503728902263511

# %%
numpregs= resp['numpregs']
resp.numpregs.mean()
# Out:
# 1.868979057591623

# %%
fmarno = resp['fmarno']
import thinkstats2
freq = thinkstats2.Hist(fmarno)
freq
# Out:
# Hist({0L: 3517L, 1L: 3436L, 2L: 582L, 3L: 90L, 4L: 15L, 5L: 3L})

# %%
for val in sorted(freq.Values()):
    print(val, freq[val])
# Out:
# 0 3517
# 1 3436
# 2 582
# 3 90
# 4 15
# 5 3

# %%
import thinkplot
width=0.5
thinkplot.Hist(freq)
thinkplot.Config(xlabel='value', ylabel='frequency', width=width)

# %%
nevermarried = resp[resp.fmarno == 0]
married = resp[resp.fmarno != 0]

nevermarried_hist = thinkstats2.Hist(nevermarried.totincr, label='neverMarried')
married_hist = thinkstats2.Hist(married.totincr, label='Married')

# %%
width = 0.5
thinkplot.PrePlot(2)
thinkplot.Hist(nevermarried_hist , align='right', width=width)
thinkplot.Hist(married_hist, align='left', width=width)
thinkplot.Config(xlabel='weeks', ylabel='Count')

# %%
minumum=resp.totincr.min()
maximum=resp.totincr.max()
mean = resp.totincr.mean()
variance = resp.totincr.var()
standarddeviation = resp.totincr.std()

# %%
minumum, maximum, mean, variance , standarddeviation
# Out:
# (1, 14, 8.8166950150464469, 15.279271096058633, 3.9088708211014893)

# %%
'nevermarried mean is : '+ str(nevermarried.totincr.mean()) + ', minumum is :'+str(nevermarried.totincr.min()) +', maximum  is:'+str(nevermarried.totincr.max()) +', variance is:'+ str(nevermarried.totincr.var())+', standartdeviation is:'+ str(nevermarried.totincr.std())
# Out:
# 'nevermarried mean is : 8.02075632641, minumum is :1, maximum  is:14, variance is:15.846838677, standartdeviation is:3.98080879683'

# %%
'married mean is : '+ str(married.totincr.mean()) + ', minumum is :'+str(married.totincr.min()) +', maximum  is:'+str(married.totincr.max()) +', variance is:'+ str(married.totincr.var())+', standartdeviation is:'+ str(married.totincr.std())
# Out:
# 'married mean is : 9.49515269026, minumum is :1, maximum  is:14, variance is:13.7986431646, standartdeviation is:3.7146524958'
